# %% [markdown]
# # Lesson: Time Series Analysis - ACQUIRE
#
# <a href="https://www.canva.com/design/DAFkDMkaEVI/eE9IYhXu7Wc6eONov2aoTA/view?utm_content=DAFkDMkaEVI&utm_campaign=designshare&utm_medium=link&utm_source=publishsharelink">![image.png](attachment:21759b99-b34b-47ed-bc2d-b324aefdaa26.png)</a>

# %% [markdown]
# <hr style="border:2px solid gray">

# %%
import pandas as pd
import requests

# %% [markdown]
# <a href="https://docs.python-requests.org/en/v2.0.0/api/">![image.png](attachment:0c8e070d-de79-456c-8a50-6f6f5aa210af.png)</a>

# %%
url = "https://101exercises.com"
response = requests.get(url)

# .text gives us back the plain text of the response.

response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n    <!-- Global site tag (gtag.js) - Google Analytics -->\n    <script async src="https://www.googletagmanager.com/gtag/js?id=UA-164560583-1"></script>\n    <script>\n      window.dataLayer = window.dataLayer || [];\n      function gtag(){dataLayer.push(arguments);}\n      gtag(\'js\', new Date());\n\n      gtag(\'config\', \'UA-164560583-1\');\n    </script>\n\n    <meta charset="UTF-8">\n    <title>101Exercises.com</title>\n    <meta name="description" content="101 Exercises for learning and practicing Python and JavaScript fundamentals data-types, operators, and functions">\n    <meta name="keywords" content="101 exercises, learn to code, JavaScript, Python, how to start programming, programming basics, programming fundamentals">\n    <meta name="author" content="Ryan Orsinger">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <link rel="icon" type="image/png" href="./img/101-hwy-sign.jpeg">\n    <link rel
# ...

# %%
response = requests.get('http://aphorisms.glitch.me/')

response.text
# Out:
# '{"quote":"I want you to double check your numbers. I want you to double check your charts. Ask yourself, does this accurately tell the story? Ask yourself, is this a good use of data? Ask yourself, is this a legit insight or am I getting caught up with how pretty the chart is and doing something that might destroy our credibility?","author":"Iris Gonzalez"}'

# %%
response
# Out:
# <Response [200]>

# %%
# returns True if status_code is less than 400, otherwise False
response.ok
# Out:
# True

# %%
# returns the actual response code
response.status_code
# Out:
# 200

# %%
response = requests.get("http://aphorisms.glitch.me/api/random")

# %%
# .json returns the parsed JSON from a response
response.json()
# Out:
# {'quote': 'Hummus is a powerful force for good in the Universe',
#  'author': 'Zach Gulde'}

# %%
# the python object after .json() will be a dictionary
type(response.json())
# Out:
# dict

# %%
# the python object after .text will be a string. It may look like a dictionary, but it is a string. 
type(response.text)
# Out:
# str

# %%
response.text
# Out:
# '{"quote":"Hummus is a powerful force for good in the Universe","author":"Zach Gulde"}'

# %%
response = requests.get("http://aphorisms.glitch.me/api/all")

# convert the reponse to json and then create a dataframe from the json structured object. 
quotes = pd.DataFrame(response.json())

# %%
response.json()
# Out:
# [{'quote': 'To go fast, go alone. To go far, go together',
#   'author': 'African Proverb'},
#  {'quote': 'In fact, the only way to manage stress is to build up your resilience and strength.',
#   'author': 'anomymous'},
#  {'quote': 'Predispose yourself to practice', 'author': 'anonymous'},
#  {'quote': 'Respect the specs', 'author': 'Dr. Linda F. Wilson'},
#  {'quote': "What we're doing is paint along with me rather than take detailed notes on the colors I use.",
#   'author': 'Zach Gulde'},
#  {'quote': "You can either honor your mood or your commitment. You'll always feel like NOT doing something.",
#   'author': 'anonymous'},
#  {'quote': "The secret to building great products is not creating awesome features, it's to make your users awesome",
#   'author': 'Kathy Sierra'},
#  {'quote': "Writing is Nature's way of exposing how sloppy your thinking is.",
#   'author': 'Guindon'},
# ...

# %%
quotes.head()
# Out:
#                                                quote               author
# 0       To go fast, go alone. To go far, go together      African Proverb
# 1  In fact, the only way to manage stress is to b...            anomymous
# 2                    Predispose yourself to practice            anonymous
# 3                                  Respect the specs  Dr. Linda F. Wilson
# 4  What we're doing is paint along with me rather...           Zach Gulde

# %% [markdown]
# ___
#
# # Star Wars API
#
# ### [SWAPI Documentation](https://swapi.dev/documentation)

# %%
# This is a URL. The end result are URI
response = requests.get('https://swapi.dev/api/')
response.json()
# Out:
# {'people': 'https://swapi.dev/api/people/',
#  'planets': 'https://swapi.dev/api/planets/',
#  'films': 'https://swapi.dev/api/films/',
#  'species': 'https://swapi.dev/api/species/',
#  'vehicles': 'https://swapi.dev/api/vehicles/',
#  'starships': 'https://swapi.dev/api/starships/'}

# %%
# Let's make it neat...

data = response.json()
data
# Out:
# {'people': 'https://swapi.dev/api/people/',
#  'planets': 'https://swapi.dev/api/planets/',
#  'films': 'https://swapi.dev/api/films/',
#  'species': 'https://swapi.dev/api/species/',
#  'vehicles': 'https://swapi.dev/api/vehicles/',
#  'starships': 'https://swapi.dev/api/starships/'}

# %%
# Focus on just `people` page

response = requests.get('https://swapi.dev/api/people/')

# %%
data = response.json()
data
# Out:
# {'count': 82,
#  'next': 'https://swapi.dev/api/people/?page=2',
#  'previous': None,
#  'results': [{'name': 'Luke Skywalker',
#    'height': '172',
#    'mass': '77',
#    'hair_color': 'blond',
#    'skin_color': 'fair',
#    'eye_color': 'blue',
#    'birth_year': '19BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.dev/api/planets/1/',
#    'films': ['https://swapi.dev/api/films/1/',
#     'https://swapi.dev/api/films/2/',
#     'https://swapi.dev/api/films/3/',
#     'https://swapi.dev/api/films/6/'],
#    'species': [],
#    'vehicles': ['https://swapi.dev/api/vehicles/14/',
#     'https://swapi.dev/api/vehicles/30/'],
#    'starships': ['https://swapi.dev/api/starships/12/',
#     'https://swapi.dev/api/starships/22/'],
#    'created': '2014-12-09T13:50:51.644000Z',
#    'edited': '2014-12-20T21:17:56.891000Z',
#    'url': 'https://swapi.dev/api/people/1/'},
#   {'name': 'C-3PO',
#    'height': '167',
#    'mass': '75',
#    'hair_color': 'n/a',
# ...

# %%
# Keeping in mind that this is technically a dict.
# Let's call certain keys

data['count']
# Out:
# 82

# %%
data['previous']

# %%
# pagination - 
data['next']
# Out:
# 'https://swapi.dev/api/people/?page=2'

# %%
data['results']
# Out:
# [{'name': 'Luke Skywalker',
#   'height': '172',
#   'mass': '77',
#   'hair_color': 'blond',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '19BBY',
#   'gender': 'male',
#   'homeworld': 'https://swapi.dev/api/planets/1/',
#   'films': ['https://swapi.dev/api/films/1/',
#    'https://swapi.dev/api/films/2/',
#    'https://swapi.dev/api/films/3/',
#    'https://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': ['https://swapi.dev/api/vehicles/14/',
#    'https://swapi.dev/api/vehicles/30/'],
#   'starships': ['https://swapi.dev/api/starships/12/',
#    'https://swapi.dev/api/starships/22/'],
#   'created': '2014-12-09T13:50:51.644000Z',
#   'edited': '2014-12-20T21:17:56.891000Z',
#   'url': 'https://swapi.dev/api/people/1/'},
#  {'name': 'C-3PO',
#   'height': '167',
#   'mass': '75',
#   'hair_color': 'n/a',
#   'skin_color': 'gold',
#   'eye_color': 'yellow',
#   'birth_year': '112BBY',
#   'gender': 'n/a',
# ...

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# This is where the carne y papas reside. Notice `results` is a **list** of several **dictionaries**. This is not the first time we have encountered this.
#
# </div>

# %%
# This is to find out how many characters (people) we have. It looks like we have 10 characters 
len(data['results'])
# Out:
# 10

# %%
number_of_people = data['count']
next_page = data['next']
previous_page = data['previous']

print(f'''number_of_people: {number_of_people}
next_page: {next_page}
previous_page: {previous_page}''')
# Out:
# number_of_people: 82
# next_page: https://swapi.dev/api/people/?page=2
# previous_page: None

# %%
import math
number_of_results = len(data['results'])
max_page = math.ceil(number_of_people / number_of_results)

print(f'''number_of_results: {number_of_results}
max_page: {max_page}''')
# Out:
# number_of_results: 10
# max_page: 9

# %%
df = pd.DataFrame(data['results'])
df
# Out:
#                  name height mass     hair_color   skin_color  eye_color  \
# 0      Luke Skywalker    172   77          blond         fair       blue
# 1               C-3PO    167   75            n/a         gold     yellow
# 2               R2-D2     96   32            n/a  white, blue        red
# 3         Darth Vader    202  136           none        white     yellow
# 4         Leia Organa    150   49          brown        light      brown
# 5           Owen Lars    178  120    brown, grey        light       blue
# 6  Beru Whitesun lars    165   75          brown        light       blue
# 7               R5-D4     97   32            n/a   white, red        red
# 8   Biggs Darklighter    183   84          black        light      brown
# 9      Obi-Wan Kenobi    182   77  auburn, white         fair  blue-gray
#
#   birth_year  gender                          homeworld  \
# 0      19BBY    male   https://swapi.dev/api/planets/1/
# ...

# %%
response = requests.get(data['next'])
data = response.json()

# %%
data
# Out:
# {'count': 82,
#  'next': 'https://swapi.dev/api/people/?page=3',
#  'previous': 'https://swapi.dev/api/people/?page=1',
#  'results': [{'name': 'Anakin Skywalker',
#    'height': '188',
#    'mass': '84',
#    'hair_color': 'blond',
#    'skin_color': 'fair',
#    'eye_color': 'blue',
#    'birth_year': '41.9BBY',
#    'gender': 'male',
#    'homeworld': 'https://swapi.dev/api/planets/1/',
#    'films': ['https://swapi.dev/api/films/4/',
#     'https://swapi.dev/api/films/5/',
#     'https://swapi.dev/api/films/6/'],
#    'species': [],
#    'vehicles': ['https://swapi.dev/api/vehicles/44/',
#     'https://swapi.dev/api/vehicles/46/'],
#    'starships': ['https://swapi.dev/api/starships/39/',
#     'https://swapi.dev/api/starships/59/',
#     'https://swapi.dev/api/starships/65/'],
#    'created': '2014-12-10T16:20:44.310000Z',
#    'edited': '2014-12-20T21:17:50.327000Z',
#    'url': 'https://swapi.dev/api/people/11/'},
#   {'name': 'Wilhuff Tarkin',
#    'height': '180',
# ...

# %%
number_of_people = data['count']
next_page = data['next']
previous_page = data['previous']
number_of_results = len(data['results'])
max_page = math.ceil(number_of_people / number_of_results)

print(f'''number_of_people: {number_of_people}
next_page: {next_page}
previous_page: {previous_page}
number_of_results: {number_of_results}
max_page: {max_page}''')
# Out:
# number_of_people: 82
# next_page: https://swapi.dev/api/people/?page=3
# previous_page: https://swapi.dev/api/people/?page=1
# number_of_results: 10
# max_page: 9

# %%
pd.concat([df, pd.DataFrame(data['results'])]).reset_index()
# Out:
#     index                   name height     mass     hair_color  \
# 0       0         Luke Skywalker    172       77          blond
# 1       1                  C-3PO    167       75            n/a
# 2       2                  R2-D2     96       32            n/a
# 3       3            Darth Vader    202      136           none
# 4       4            Leia Organa    150       49          brown
# 5       5              Owen Lars    178      120    brown, grey
# 6       6     Beru Whitesun lars    165       75          brown
# 7       7                  R5-D4     97       32            n/a
# 8       8      Biggs Darklighter    183       84          black
# 9       9         Obi-Wan Kenobi    182       77  auburn, white
# 10      0       Anakin Skywalker    188       84          blond
# 11      1         Wilhuff Tarkin    180  unknown   auburn, grey
# 12      2              Chewbacca    228      112          brown
# 13      3               Han Solo    180       80          brown
# ...

# %%
url = "https://swapi.dev/api/people/?page=9"
response = requests.get(url)
data = response.json()

number_of_people = data['count']
next_page = data ['next']
previous_page = data['previous']
number_of_results = len(data['results'])

print(f'''number_of_people: {number_of_people}
next_page: {next_page}
previous_page: {previous_page}
number_of_results: {number_of_results}''')
# Out:
# number_of_people: 82
# next_page: None
# previous_page: https://swapi.dev/api/people/?page=8
# number_of_results: 2

# %%
base_url = "https://swapi.dev/api/"

base_url + "people/"
# Out:
# 'https://swapi.dev/api/people/'

# %%
ppl_url = base_url + "people/"

requests.get(ppl_url + "?page=8").json()
# Out:
# {'count': 82,
#  'next': 'https://swapi.dev/api/people/?page=9',
#  'previous': 'https://swapi.dev/api/people/?page=7',
#  'results': [{'name': 'Lama Su',
#    'height': '229',
#    'mass': '88',
#    'hair_color': 'none',
#    'skin_color': 'grey',
#    'eye_color': 'black',
#    'birth_year': 'unknown',
#    'gender': 'male',
#    'homeworld': 'https://swapi.dev/api/planets/10/',
#    'films': ['https://swapi.dev/api/films/5/'],
#    'species': ['https://swapi.dev/api/species/32/'],
#    'vehicles': [],
#    'starships': [],
#    'created': '2014-12-20T17:30:50.416000Z',
#    'edited': '2014-12-20T21:17:50.473000Z',
#    'url': 'https://swapi.dev/api/people/72/'},
#   {'name': 'Taun We',
#    'height': '213',
#    'mass': 'unknown',
#    'hair_color': 'none',
#    'skin_color': 'grey',
#    'eye_color': 'black',
#    'birth_year': 'unknown',
#    'gender': 'female',
#    'homeworld': 'https://swapi.dev/api/planets/10/',
#    'films': ['https://swapi.dev/api/films/5/'],
# ...

# %% [markdown]
# ## Guidance for the exercise
#
# 1. Setup
#     - url (base + endpoint)
#     - empty list
# 1. Loop
#     1. make a request
#     1. handle the response, add to the list
#     1. find the next url endpoint
#         1. if it's None, stop looping
#         1. if it's a string, use it to construct the next url
# 1. Turn the list into a dataframe
#
# General Tips
#
# - solve an easy problem first (the items endpoint), then apply that solution to the larger problem (sales)
# - informational print statements are helpful as you are developing code, especially inside of a loop to see what changes
# - Dont' be afraid to command + shift + p (command + shift + c for jupyter lab) "interrupt the kernel"
# ___

# %% [markdown]
# ## Extra Resource:
# <a href = "https://drive.google.com/file/d/1hpq5e8SBWLA37OZXc5rLs5bH2DmNJcJA/view?usp=share_link">![image.png](attachment:f605b94c-a6e5-4857-9c09-7bf51ffae676.png)</a>
