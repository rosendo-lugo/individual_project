# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

from pydataset import data

# # module for visualizations
# import viz_kmeans as vk

# my imports
import wrangle_lugo_copy as w

# %%
df = w.get_wine_data()

# %%
df = w.prep_wine_data(df)

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.4              0.70         0.00             1.9      0.076
# 2            7.4              0.66         0.00             1.8      0.075
# 3            7.9              0.60         0.06             1.6      0.069
# 4            7.3              0.65         0.00             1.2      0.065
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    ph  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 11.0                  34.0   0.9978  3.51       0.56
# 2                 13.0                  40.0   0.9978  3.51       0.56
# 3                 15.0                  59.0   0.9964  3.30       0.46
# 4                 15.0                  21.0   0.9946  3.39       0.47
#
#    alcohol  quality wine_type  wine_type_white_wine
# 0      9.4        5  red_wine                     0
# 1      9.4        5  red_wine                     0
# 2      9.4        5  red_wine                     0
# 3      9.4        5  red_wine                     0
# 4     10.0        7  red_wine                     0

# %%
# dropping these columns for right now until I find a use for them
# df = df.drop(columns =['wine_type','wine_type_white_wine'])
df = df.drop(columns =['wine_type'])

# %%
tr, val, ts = w.get_split(df)
tr.shape, val.shape, ts.shape
# Out:
# ((3378, 13), (1126, 13), (1126, 13))

# %%
target = 'quality'
X_tr, X_val, X_ts, y_tr, y_val, y_ts, to_scale, baseline = w.get_Xs_ys_to_scale_baseline(tr, val, ts, target)
baseline
# Out:
# 5.867377146240379

# %%
X_tr_sc, X_val_sc, X_ts_sc = w.scale_data(X_tr,X_val,X_ts,to_scale)
X_tr_sc.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 2336       0.285714          0.526316     0.476190        0.252475   0.322581
# 3295       0.476190          0.526316     0.444444        0.435644   0.505376
# 3018       0.571429          0.270677     0.825397        0.623762   0.408602
# 3712       0.428571          0.496241     0.492063        0.049505   0.354839
# 4948       0.476190          0.240602     0.634921        0.732673   0.462366
#
#       free_sulfur_dioxide  total_sulfur_dioxide   density    ph  sulphates  \
# 2336             0.267442              0.333333  0.329293  0.82   0.537313
# 3295             0.325581              0.641304  0.594613  0.45   0.268657
# 3018             0.732558              0.626812  0.746801  0.38   0.313433
# 3712             0.197674              0.344203  0.325926  0.41   0.238806
# 4948             0.930233              0.695652  0.773737  0.48   0.656716
#
#        alcohol  wine_type_white_wine
# 2336  0.696429                   1.0
# 3295  0.178571                   1.0
# 3018  0.107143                   1.0
# 3712  0.375000                   1.0
# 4948  0.178571                   1.0

# %%
## ABOVE is from Rosendo; now I explore

# %%
import corey_explore as ce

# %%
tr.head().T
# Out:
#                         2336       3295      3018       3712      4948
# fixed_acidity          5.700    6.90000    7.5000    6.60000    6.9000
# volatile_acidity       0.430    0.43000    0.2600    0.41000    0.2400
# citric_acid            0.300    0.28000    0.5200    0.31000    0.4000
# residual_sugar         5.700    9.40000   13.2000    1.60000   15.4000
# chlorides              0.039    0.05600    0.0470    0.04200    0.0520
# free_sulfur_dioxide   24.000   29.00000   64.0000   18.00000   81.0000
# total_sulfur_dioxide  98.000  183.00000  179.0000  101.00000  198.0000
# density                0.992    0.99594    0.9982    0.99195    0.9986
# ph                     3.540    3.17000    3.1000    3.13000    3.2000
# sulphates              0.610    0.43000    0.4600    0.41000    0.6900
# alcohol               12.300    9.40000    9.0000   10.50000    9.4000
# quality                7.000    5.00000    5.0000    5.00000    5.0000
# wine_type_white_wine   1.000    1.00000    1.0000    1.00000    1.0000

# %%
wine_corr = tr.corr()
wine_corr
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000          0.184528     0.222014
# volatile_acidity           0.184528          1.000000    -0.460411
# citric_acid                0.222014         -0.460411     1.000000
# residual_sugar            -0.046879         -0.189299     0.165323
# chlorides                  0.366731          0.504305    -0.213161
# free_sulfur_dioxide       -0.184794         -0.348819     0.208377
# total_sulfur_dioxide      -0.182726         -0.400544     0.288760
# density                    0.380595          0.203533     0.005892
# ph                        -0.262537          0.248925    -0.286020
# sulphates                  0.162212          0.206489    -0.039633
# alcohol                   -0.142757         -0.019722     0.026039
# quality                   -0.099324         -0.232037     0.109794
# wine_type_white_wine      -0.367778         -0.651995     0.318760
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# fixed_acidity              -0.046879   0.366731            -0.184794
# volatile_acidity           -0.189299   0.504305            -0.348819
# citric_acid                 0.165323  -0.213161             0.208377
# residual_sugar              1.000000  -0.104039             0.437943
# chlorides                  -0.104039   1.000000            -0.251531
# free_sulfur_dioxide         0.437943  -0.251531             1.000000
# total_sulfur_dioxide        0.498015  -0.339137             0.707619
# density                     0.624906   0.524948             0.135802
# ph                         -0.284264   0.244482            -0.173309
# sulphates                  -0.151775   0.344149            -0.140681
# alcohol                    -0.398710  -0.368440            -0.192024
# quality                    -0.051198  -0.271426             0.075344
# wine_type_white_wine        0.318425  -0.744545             0.431400
#
#                       total_sulfur_dioxide   density        ph  sulphates  \
# fixed_acidity                    -0.182726  0.380595 -0.262537   0.162212
# volatile_acidity                 -0.400544  0.203533  0.248925   0.206489
# citric_acid                       0.288760  0.005892 -0.286020  -0.039633
# residual_sugar                    0.498015  0.624906 -0.284264  -0.151775
# chlorides                        -0.339137  0.524948  0.244482   0.344149
# free_sulfur_dioxide               0.707619  0.135802 -0.173309  -0.140681
# total_sulfur_dioxide              1.000000  0.160108 -0.271162  -0.217290
# density                           0.160108  1.000000  0.039801   0.209468
# ph                               -0.271162  0.039801  1.000000   0.299363
# sulphates                        -0.217290  0.209468  0.299363   1.000000
# alcohol                          -0.288652 -0.770281  0.080941  -0.010792
# quality                          -0.046843 -0.327809  0.034522   0.056060
# wine_type_white_wine              0.653413 -0.320644 -0.391020  -0.439033
#
#                        alcohol   quality  wine_type_white_wine
# fixed_acidity        -0.142757 -0.099324             -0.367778
# volatile_acidity     -0.019722 -0.232037             -0.651995
# citric_acid           0.026039  0.109794              0.318760
# residual_sugar       -0.398710 -0.051198              0.318425
# chlorides            -0.368440 -0.271426             -0.744545
# free_sulfur_dioxide  -0.192024  0.075344              0.431400
# total_sulfur_dioxide -0.288652 -0.046843              0.653413
# density              -0.770281 -0.327809             -0.320644
# ph                    0.080941  0.034522             -0.391020
# sulphates            -0.010792  0.056060             -0.439033
# alcohol               1.000000  0.456713              0.050350
# quality               0.456713  1.000000              0.125896
# wine_type_white_wine  0.050350  0.125896              1.000000

# %%
# Next, pass correlation matrix to sns.heatmap
plt.figure(figsize=(8,6))
sns.heatmap(wine_corr, mask=np.triu(wine_corr))
plt.show()

# %%
# Next, pass correlation matrix to sns.heatmap
plt.figure(figsize=(8,6))
sns.heatmap(wine_corr.abs(), cmap='Purples', mask=np.triu(wine_corr))
plt.show()

# %%
# make a list of the feature/column names to conduct vis/stat tests on
features = list(tr.drop(columns = [target]).columns)
features
# Out:
# ['fixed_acidity',
#  'volatile_acidity',
#  'citric_acid',
#  'residual_sugar',
#  'chlorides',
#  'free_sulfur_dioxide',
#  'total_sulfur_dioxide',
#  'density',
#  'ph',
#  'sulphates',
#  'alcohol',
#  'wine_type_white_wine']

# %%
sns.pairplot(data=tr, kind='reg', corner=True, hue='wine_type_white_wine')
plt.show()

# %%
from scipy.stats import levene
from scipy.stats import spearmanr

# %%
# all variables are continuous and I want to compare them to quality, a continuous variable
# pairplot showed roughly normal dist for all but residual_sugar, but I have > 500 observations; so normal
# BUT, a levene test showed equal_variance to be false for all, so use spearmanr
# - Spearmanr for the stat test to check for correlation 
# - H0: the feature-target pair is not correlated, Ha: they are correlated

# will check for equal variance with levene test 
# - from documentation: "small p-value suggests that the populations do not have equal variances"
# - H0: feature-target pair have equal variance, Ha: not equal variance
# - a p < .05 suggests not equal variance and we will set that value to False in the SpearmansR test

def get_spearmanr_regplots(df, target):
    """
    This function will
    - accept a dataframe with continuous variables and the target column, also continuous
    - accept a string which is the name of the target column
    - prints regplots of each feature vs the target
    - returns a dataframe with results of levene test for equal variance and spearmanr 
      test for correlation on each feature vs target
    """
    # target = 'quality'
    features = list(df.drop(columns = [target]).columns)
    results_list = []

    for col in features:
        lt, lp = levene(df[col], df[target])
        if lp < .05: 
            eq_var = False
        else: 
            eq_var = True

        t, p = spearmanr(df[col], df[target])

        sns.regplot(df[col], df[target], scatter_kws = {"color": "black", "alpha": 0.5}
                    , line_kws = {"color": "red"})
        if p < .05:
            plt.title('p < alpha: suggest H_a (correlated)')
            p_string = 'REJECT H0, suggests H_a (correlated)'
        else:
            plt.title('p >= alpha: cannot reject H_0 (not correlated)')
            p_string = 'CANNOT reject H0 (no correlation)'
        plt.show()

        results_list.append([col, lp, eq_var, t, p, p_string])

    results_df = pd.DataFrame(results_list, columns=['column','levene p', 'equal_var', 'spearmanr t'
                                                     , 'spearmanr p', 'hypothesis result'])
    return results_df

# %%
get_spearmanr_regplots(tr, 'quality')
# Out:
#                   column       levene p  equal_var  spearmanr t  \
# 0          fixed_acidity   8.540429e-11      False    -0.094003
# 1       volatile_acidity   0.000000e+00      False    -0.234938
# 2            citric_acid   0.000000e+00      False     0.119492
# 3         residual_sugar   0.000000e+00      False    -0.029566
# 4              chlorides   0.000000e+00      False    -0.314516
# 5    free_sulfur_dioxide   0.000000e+00      False     0.091264
# 6   total_sulfur_dioxide   0.000000e+00      False    -0.068898
# 7                density   0.000000e+00      False    -0.347302
# 8                     ph   0.000000e+00      False     0.045900
# 9              sulphates   0.000000e+00      False     0.034406
# 10               alcohol  1.058787e-121      False     0.462349
# 11  wine_type_white_wine  4.280711e-266      False     0.132066
#
#       spearmanr p                     hypothesis result
# 0    4.409316e-08  REJECT H0, suggests H_a (correlated)
# 1    1.385305e-43  REJECT H0, suggests H_a (correlated)
# 2    3.229909e-12  REJECT H0, suggests H_a (correlated)
# 3    8.577753e-02     CANNOT reject H0 (no correlation)
# 4    1.902966e-78  REJECT H0, suggests H_a (correlated)
# 5    1.075687e-07  REJECT H0, suggests H_a (correlated)
# 6    6.131864e-05  REJECT H0, suggests H_a (correlated)
# 7    2.328684e-96  REJECT H0, suggests H_a (correlated)
# 8    7.627276e-03  REJECT H0, suggests H_a (correlated)
# 9    4.554647e-02  REJECT H0, suggests H_a (correlated)
# 10  1.456181e-178  REJECT H0, suggests H_a (correlated)
# 11   1.291366e-14  REJECT H0, suggests H_a (correlated)

# %%
# -.8 for t (very highly correlated; maybe take out density and just use alcohol)
spearmanr(tr.alcohol, tr.density)
# Out:
# SpearmanrResult(correlation=-0.7729668005975888, pvalue=0.0)

# %%
X_tr_sc.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 2336       0.285714          0.526316     0.476190        0.252475   0.322581
# 3295       0.476190          0.526316     0.444444        0.435644   0.505376
# 3018       0.571429          0.270677     0.825397        0.623762   0.408602
# 3712       0.428571          0.496241     0.492063        0.049505   0.354839
# 4948       0.476190          0.240602     0.634921        0.732673   0.462366
#
#       free_sulfur_dioxide  total_sulfur_dioxide   density    ph  sulphates  \
# 2336             0.267442              0.333333  0.329293  0.82   0.537313
# 3295             0.325581              0.641304  0.594613  0.45   0.268657
# 3018             0.732558              0.626812  0.746801  0.38   0.313433
# 3712             0.197674              0.344203  0.325926  0.41   0.238806
# 4948             0.930233              0.695652  0.773737  0.48   0.656716
#
#        alcohol  wine_type_white_wine
# 2336  0.696429                   1.0
# 3295  0.178571                   1.0
# 3018  0.107143                   1.0
# 3712  0.375000                   1.0
# 4948  0.178571                   1.0

# %%
# free sulfur dioxide and sulphates were not correlated, and
# density is highly correlated with alcohol (repeated info)
drop_cols = ['free_sulfur_dioxide', 'sulphates', 'density']

# %%
ce.get_kbest_multi(X_tr_sc.drop(columns=drop_cols), y_tr)
# Out:
#                 Feature  KBest Rank  KBest Scores
# 0               alcohol           1    889.785570
# 1             chlorides           2    268.497955
# 2      volatile_acidity           3    192.111591
# 3  wine_type_white_wine           4     54.370987
# 4           citric_acid           5     41.193683
# 5         fixed_acidity           6     33.637017
# 6        residual_sugar           7      8.872617
# 7  total_sulfur_dioxide           8      7.424043
# 8                    ph           9      4.028109

# %%
ce.get_rfe_multi(X_tr_sc.drop(columns=drop_cols), y_tr)
# Out:
#                 Feature  RFE Rank
# 7               alcohol         1
# 1      volatile_acidity         2
# 3        residual_sugar         3
# 6                    ph         4
# 8  wine_type_white_wine         5
# 4             chlorides         6
# 0         fixed_acidity         7
# 2           citric_acid         8
# 5  total_sulfur_dioxide         9

# %%
# now I want to do all of that with separate databases (red vs white)
red_tr = tr[tr.wine_type_white_wine == 0]
white_tr = tr[tr.wine_type_white_wine == 1]

# %%
red_tr.shape, white_tr.shape
# Out:
# ((613, 13), (2765, 13))

# %%
get_spearmanr_regplots(red_tr, 'quality')
# Out:
#                   column       levene p  equal_var  spearmanr t   spearmanr p  \
# 0          fixed_acidity   1.321483e-15      False     0.057941  1.519080e-01
# 1       volatile_acidity  5.115796e-103      False    -0.340242  4.448436e-18
# 2            citric_acid   9.647944e-95      False     0.143863  3.526342e-04
# 3         residual_sugar   5.501476e-01       True    -0.002139  9.578527e-01
# 4              chlorides  2.180246e-137      False    -0.145265  3.080795e-04
# 5    free_sulfur_dioxide  2.798645e-111      False    -0.021510  5.950408e-01
# 6   total_sulfur_dioxide  1.272700e-116      False    -0.193676  1.356906e-06
# 7                density  3.344853e-140      False    -0.243819  9.541710e-10
# 8                     ph  1.685772e-105      False     0.022226  5.828470e-01
# 9              sulphates  4.443479e-110      False     0.417908  2.616717e-27
# 10               alcohol   6.715186e-11      False     0.490929  1.688035e-38
# 11  wine_type_white_wine  1.203149e-140      False          NaN           NaN
#
#                        hypothesis result
# 0      CANNOT reject H0 (no correlation)
# 1   REJECT H0, suggests H_a (correlated)
# 2   REJECT H0, suggests H_a (correlated)
# 3      CANNOT reject H0 (no correlation)
# 4   REJECT H0, suggests H_a (correlated)
# 5      CANNOT reject H0 (no correlation)
# 6   REJECT H0, suggests H_a (correlated)
# 7   REJECT H0, suggests H_a (correlated)
# 8      CANNOT reject H0 (no correlation)
# 9   REJECT H0, suggests H_a (correlated)
# 10  REJECT H0, suggests H_a (correlated)
# 11     CANNOT reject H0 (no correlation)

# %%
get_spearmanr_regplots(white_tr, 'quality')
# Out:
#                   column       levene p  equal_var  spearmanr t  \
# 0          fixed_acidity   8.277424e-01       True    -0.070755
# 1       volatile_acidity   0.000000e+00      False    -0.177593
# 2            citric_acid   0.000000e+00      False     0.056727
# 3         residual_sugar   0.000000e+00      False    -0.089824
# 4              chlorides   0.000000e+00      False    -0.320187
# 5    free_sulfur_dioxide   0.000000e+00      False     0.024392
# 6   total_sulfur_dioxide   0.000000e+00      False    -0.194596
# 7                density   0.000000e+00      False    -0.353195
# 8                     ph   0.000000e+00      False     0.115620
# 9              sulphates   0.000000e+00      False     0.052701
# 10               alcohol  2.556249e-108      False     0.456968
# 11  wine_type_white_wine   0.000000e+00      False          NaN
#
#       spearmanr p                     hypothesis result
# 0    1.964793e-04  REJECT H0, suggests H_a (correlated)
# 1    5.003762e-21  REJECT H0, suggests H_a (correlated)
# 2    2.845622e-03  REJECT H0, suggests H_a (correlated)
# 3    2.237812e-06  REJECT H0, suggests H_a (correlated)
# 4    6.004043e-67  REJECT H0, suggests H_a (correlated)
# 5    1.997640e-01     CANNOT reject H0 (no correlation)
# 6    5.335031e-25  REJECT H0, suggests H_a (correlated)
# 7    4.898222e-82  REJECT H0, suggests H_a (correlated)
# 8    1.078021e-09  REJECT H0, suggests H_a (correlated)
# 9    5.573203e-03  REJECT H0, suggests H_a (correlated)
# 10  9.734143e-143  REJECT H0, suggests H_a (correlated)
# 11            NaN     CANNOT reject H0 (no correlation)

# %%
# kbest for red wines
##### CAN't DO unless I redo y_tr to be only red wine quality scores, too #####
#ce.get_kbest_multi(X_tr_sc[X_tr_sc.wine_type_white_wine == 0].drop(columns=drop_cols), y_tr)
